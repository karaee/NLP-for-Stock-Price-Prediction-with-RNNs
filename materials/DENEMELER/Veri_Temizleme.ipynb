# %%
import pandas as pd
import numpy as np

# %%
df_rate = pd.read_csv("akbank_rates.csv")

# %%
type(df_rate.Tarih)
# Out:
# pandas.core.series.Series

# %%
type(df.date)
# Out:
# pandas.core.series.Series

# %%
df_rate = df_rate[:1332]

# %%
df_rate.head()
# Out:
#         Tarih Şimdi Açılış Yüksek Düşük     Hac.  Fark %
# 0  25.09.2020   5,1   5,17   5,21  5,09  150,14M   1,19%
# 1  24.09.2020  5,04   4,74   5,06  4,74  229,86M   5,88%
# 2  23.09.2020  4,76   4,76   4,83  4,74   62,91M   0,42%
# 3  22.09.2020  4,74   4,73   4,77  4,71   44,19M   0,42%
# 4  21.09.2020  4,72   4,87   4,88   4,7   70,84M  -3,08%

# %%
df = pd.read_csv("Akbank_haber.csv")

# %%
df.head(100
    )
# Out:
#                                           title  \
# 0                Endekste 101.000 sağlam destek
# 1   Analistlerden sanayi verisi yorumları geldi
# 2           Bankalar uçarken havayolları iniyor
# 3     Şirket haberleri ve tavsiyeleri 13/3/2019
# 4     Şirket haberleri ve tavsiyeleri 12/3/2019
# ..                                          ...
# 95                   Vergi borcu olanlar dikkat
# 96            Bilançolarıyla öne çıkan hisseler
# 97   Şirket haberleri ve tavsiyeleri 23/11/2018
# 98     Günün önemli şirket haberleri 23/11/2018
# 99    İki banka hissesinde hedef fiyat yükseldi
#
#                                               content           date   time
# 0   BIST 100, 103 bini aşağı geçtiğinde hedge şart...   15 Mart 2019  09:27
# 1                                                 NaN   14 Mart 2019  13:56
# 2   BOEING'in üretiminde kusurlu olup olmadığı inc...   14 Mart 2019  10:00
# 3   AKBNK, EREGL,THYAO, başta olmak üzere günün ön...   13 Mart 2019  08:59
# ...

# %%
df.date
# Out:
# 0          15 Mart 2019
# 1          14 Mart 2019
# 2          14 Mart 2019
# 3          13 Mart 2019
# 4          12 Mart 2019
#              ...
# 2075    15 Haziran 2015
# 2076    12 Haziran 2015
# 2077    11 Haziran 2015
# 2078    09 Haziran 2015
# 2079    09 Haziran 2015
# Name: date, Length: 2080, dtype: object

# %%
df.date[2050:]
# Out:
# 2050     26 Temmuz 2015
# 2051     20 Temmuz 2015
# 2052     14 Temmuz 2015
# 2053     14 Temmuz 2015
# 2054     13 Temmuz 2015
# 2055     10 Temmuz 2015
# 2056     09 Temmuz 2015
# 2057     09 Temmuz 2015
# 2058     08 Temmuz 2015
# 2059     06 Temmuz 2015
# 2060     01 Temmuz 2015
# 2061    30 Haziran 2015
# 2062    30 Haziran 2015
# 2063    29 Haziran 2015
# 2064    29 Haziran 2015
# 2065    25 Haziran 2015
# 2066    25 Haziran 2015
# 2067    24 Haziran 2015
# 2068    24 Haziran 2015
# 2069    24 Haziran 2015
# 2070    22 Haziran 2015
# 2071    18 Haziran 2015
# 2072    17 Haziran 2015
# 2073    16 Haziran 2015
# 2074    15 Haziran 2015
# 2075    15 Haziran 2015
# 2076    12 Haziran 2015
# 2077    11 Haziran 2015
# 2078    09 Haziran 2015
# 2079    09 Haziran 2015
# Name: date, dtype: object

# %% [markdown]
# ## MERGE

# %%
df_merge = df.merge(df_rate, left_on = "Tarih", right_on = "Tarih")

# %%
df_merge.head()
# Out:
#                                          title  \
# 0               Endekste 101.000 sağlam destek
# 1  Analistlerden sanayi verisi yorumları geldi
# 2          Bankalar uçarken havayolları iniyor
# 3    Şirket haberleri ve tavsiyeleri 13/3/2019
# 4    Şirket haberleri ve tavsiyeleri 12/3/2019
#
#                                              content       Tarih   time Şimdi  \
# 0  BIST 100, 103 bini aşağı geçtiğinde hedge şart...  15.03.2019  09:27  6,69
# 1                                                NaN  15.03.2019  13:56  6,69
# 2  BOEING'in üretiminde kusurlu olup olmadığı inc...  15.03.2019  10:00  6,69
# 3  AKBNK, EREGL,THYAO, başta olmak üzere günün ön...  15.03.2019  08:59  6,69
# 4  ALARK,EKGYO,GOLTS başta olmak üzere günün önem...  15.03.2019  09:10  6,69
#
#   Açılış Yüksek Düşük    Hac. Fark %
# 0    6,6   6,72  6,59  49,80M  1,83%
# 1    6,6   6,72  6,59  49,80M  1,83%
# 2    6,6   6,72  6,59  49,80M  1,83%
# 3    6,6   6,72  6,59  49,80M  1,83%
# ...

# %%
df_merge.tail()
# Out:
#                                              title  \
# 2075                   22 hisse için teknik analiz
# 2076               Kamu bankaları borsada düşüyor!
# 2077  Akbank Direkt'in kârı 150 şube kârına ulaştı
# 2078               İşte Türkiye'den çıkacak devler
# 2079          Türk bankaları için çok önemli uyarı
#
#                                                 content        date   time  \
# 2075  Uzmanlar yirmiiki hisse için teknik analizde b...  15.03.2019  10:35
# 2076  Kamu bankaları borsada özel bankalara göre neg...  15.03.2019  13:14
# 2077  Hergün neredeyse 5000 yeni müşterinin tanıştığ...  15.03.2019  06:29
# 2078  Türkiye’ye olan yabancı ilgisi kadar Türkiye’d...  15.03.2019  13:12
# 2079  Barclays'e göre Türk bankalarında alım yapmak ...  15.03.2019  10:36
#
#            Tarih Şimdi Açılış Yüksek Düşük    Hac. Fark %
# 2075  15.03.2019  6,69    6,6   6,72  6,59  49,80M  1,83%
# 2076  15.03.2019  6,69    6,6   6,72  6,59  49,80M  1,83%
# ...

# %% [markdown]
# ## CONCAT

# %%
df_concat = pd.concat([df_rate,df], axis = 1)

# %%
df_concat
# Out:
#            Tarih Şimdi Açılış Yüksek Düşük     Hac.  Fark %  \
# 0     25.09.2020   5,1   5,17   5,21  5,09  150,14M   1,19%
# 1     24.09.2020  5,04   4,74   5,06  4,74  229,86M   5,88%
# 2     23.09.2020  4,76   4,76   4,83  4,74   62,91M   0,42%
# 3     22.09.2020  4,74   4,73   4,77  4,71   44,19M   0,42%
# 4     21.09.2020  4,72   4,87   4,88   4,7   70,84M  -3,08%
# ...          ...   ...    ...    ...   ...      ...     ...
# 2075         NaN   NaN    NaN    NaN   NaN      NaN     NaN
# 2076         NaN   NaN    NaN    NaN   NaN      NaN     NaN
# 2077         NaN   NaN    NaN    NaN   NaN      NaN     NaN
# 2078         NaN   NaN    NaN    NaN   NaN      NaN     NaN
# 2079         NaN   NaN    NaN    NaN   NaN      NaN     NaN
#
#                                              title  \
# 0                   Endekste 101.000 sağlam destek
# 1      Analistlerden sanayi verisi yorumları geldi
# 2              Bankalar uçarken havayolları iniyor
# ...

# %% [markdown]
# ## REPLACE INT

# %%
for i in df.date:
    print(i)
# Out:
# 15 Mart 2019
# 14 Mart 2019
# 14 Mart 2019
# 13 Mart 2019
# 12 Mart 2019
# 08 Mart 2019
# 06 Mart 2019
# 04 Mart 2019
# 04 Mart 2019
# 04 Mart 2019
# 02 Mart 2019
# 28 Şubat 2019
# 25 Şubat 2019
# 25 Şubat 2019
# 22 Şubat 2019
# 19 Şubat 2019
# 13 Şubat 2019
# 11 Şubat 2019
# 07 Şubat 2019
# 06 Şubat 2019
# 06 Şubat 2019
# 04 Şubat 2019
# 04 Şubat 2019
# 01 Şubat 2019
# 01 Şubat 2019
# 01 Şubat 2019
# 31 Ocak 2019
# 31 Ocak 2019
# 31 Ocak 2019
# 28 Ocak 2019
# 25 Ocak 2019
# 24 Ocak 2019
# 24 Ocak 2019
# 22 Ocak 2019
# 21 Ocak 2019
# 21 Ocak 2019
# 21 Ocak 2019
# 19 Ocak 2019
# 18 Ocak 2019
# 18 Ocak 2019
# 18 Ocak 2019
# 17 Ocak 2019
# 16 Ocak 2019
# 15 Ocak 2019
# 15 Ocak 2019
# 15 Ocak 2019
# 11 Ocak 2019
# 10 Ocak 2019
# 10 Ocak 2019
# 09 Ocak 2019
# 09 Ocak 2019
# 08 Ocak 2019
# 08 Ocak 2019
# 07 Ocak 2019
# 07 Ocak 2019
# 07 Ocak 2019
# 07 Ocak 2019
# 04 Ocak 2019
# 04 Ocak 2019
# 04 Ocak 2019
# 03 Ocak 2019
# 02 Ocak 2019
# 02 Ocak 2019
# 02 Ocak 2019
# 28 Aralık 2018
# ...

# %%
df.date=df.date.str.replace("Mart","03")

# %%
df.date=df.date.str.replace("Nisan","04")

# %%
df.date=df.date.str.replace("Mayıs","05")

# %%
df.date=df.date.str.replace("Haziran","06")

# %%
df.date=df.date.str.replace("Temmuz","07")

# %%
df.date=df.date.str.replace("Ağustos","08")

# %%
df.date=df.date.str.replace("Eylül","09")

# %%
df.date=df.date.str.replace("Ekim","10")

# %%
df.date=df.date.str.replace("Kasım","11")

# %%
df.date=df.date.str.replace("Aralık","12")

# %%
df.date=df.date.str.replace("Ocak","01")

# %%
df.date=df.date.str.replace("Şubat","02")

# %%
df
# Out:
#                                              title  \
# 0                   Endekste 101.000 sağlam destek
# 1      Analistlerden sanayi verisi yorumları geldi
# 2              Bankalar uçarken havayolları iniyor
# 3        Şirket haberleri ve tavsiyeleri 13/3/2019
# 4        Şirket haberleri ve tavsiyeleri 12/3/2019
# ...                                            ...
# 2075                   22 hisse için teknik analiz
# 2076               Kamu bankaları borsada düşüyor!
# 2077  Akbank Direkt'in kârı 150 şube kârına ulaştı
# 2078               İşte Türkiye'den çıkacak devler
# 2079          Türk bankaları için çok önemli uyarı
#
#                                                 content        date   time
# 0     BIST 100, 103 bini aşağı geçtiğinde hedge şart...  15 03 2019  09:27
# 1                                                   NaN  14 03 2019  13:56
# 2     BOEING'in üretiminde kusurlu olup olmadığı inc...  14 03 2019  10:00
# ...

# %% [markdown]
# ## REPLACE "."

# %%
for i in df.Tarih:
    df.Tarih = i.replace(" ",".")

# %%
df
# Out:
#                                              title  \
# 0                   Endekste 101.000 sağlam destek
# 1      Analistlerden sanayi verisi yorumları geldi
# 2              Bankalar uçarken havayolları iniyor
# 3        Şirket haberleri ve tavsiyeleri 13/3/2019
# 4        Şirket haberleri ve tavsiyeleri 12/3/2019
# ...                                            ...
# 2075                   22 hisse için teknik analiz
# 2076               Kamu bankaları borsada düşüyor!
# 2077  Akbank Direkt'in kârı 150 şube kârına ulaştı
# 2078               İşte Türkiye'den çıkacak devler
# 2079          Türk bankaları için çok önemli uyarı
#
#                                                 content        date   time
# 0     BIST 100, 103 bini aşağı geçtiğinde hedge şart...  15.03.2019  09:27
# 1                                                   NaN  15.03.2019  13:56
# 2     BOEING'in üretiminde kusurlu olup olmadığı inc...  15.03.2019  10:00
# ...

# %%
df.head()
# Out:
#                                          title  \
# 0               Endekste 101.000 sağlam destek
# 1  Analistlerden sanayi verisi yorumları geldi
# 2          Bankalar uçarken havayolları iniyor
# 3    Şirket haberleri ve tavsiyeleri 13/3/2019
# 4    Şirket haberleri ve tavsiyeleri 12/3/2019
#
#                                              content        date   time
# 0  BIST 100, 103 bini aşağı geçtiğinde hedge şart...  15.03.2019  09:27
# 1                                                NaN  15.03.2019  13:56
# 2  BOEING'in üretiminde kusurlu olup olmadığı inc...  15.03.2019  10:00
# 3  AKBNK, EREGL,THYAO, başta olmak üzere günün ön...  15.03.2019  08:59
# 4  ALARK,EKGYO,GOLTS başta olmak üzere günün önem...  15.03.2019  09:10

# %%
df_rate.head()
# Out:
#         Tarih Şimdi Açılış Yüksek Düşük     Hac.  Fark %
# 0  25.09.2020   5,1   5,17   5,21  5,09  150,14M   1,19%
# 1  24.09.2020  5,04   4,74   5,06  4,74  229,86M   5,88%
# 2  23.09.2020  4,76   4,76   4,83  4,74   62,91M   0,42%
# 3  22.09.2020  4,74   4,73   4,77  4,71   44,19M   0,42%
# 4  21.09.2020  4,72   4,87   4,88   4,7   70,84M  -3,08%

# %%
df.date.rename("Tarih", inplace = True)
# Out:
# 0       15 03 2019
# 1       14 03 2019
# 2       14 03 2019
# 3       13 03 2019
# 4       12 03 2019
#            ...
# 2075    15 06 2015
# 2076    12 06 2015
# 2077    11 06 2015
# 2078    09 06 2015
# 2079    09 06 2015
# Name: Tarih, Length: 2080, dtype: object

# %%
df
# Out:
#                                              title  \
# 0                   Endekste 101.000 sağlam destek
# 1      Analistlerden sanayi verisi yorumları geldi
# 2              Bankalar uçarken havayolları iniyor
# 3        Şirket haberleri ve tavsiyeleri 13/3/2019
# 4        Şirket haberleri ve tavsiyeleri 12/3/2019
# ...                                            ...
# 2075                   22 hisse için teknik analiz
# 2076               Kamu bankaları borsada düşüyor!
# 2077  Akbank Direkt'in kârı 150 şube kârına ulaştı
# 2078               İşte Türkiye'den çıkacak devler
# 2079          Türk bankaları için çok önemli uyarı
#
#                                                 content       Tarih   time
# 0     BIST 100, 103 bini aşağı geçtiğinde hedge şart...  15.03.2019  09:27
# 1                                                   NaN  15.03.2019  13:56
# 2     BOEING'in üretiminde kusurlu olup olmadığı inc...  15.03.2019  10:00
# ...

# %%
df.rename(columns={"date":"Tarih"},inplace = True)

# %%
kolonlar = {"title","content","Tarih","time"}

# %%
df_rate.merge(df, on="date")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-176-1ad12929759a> in <module>
# ----> 1 df_rate.merge(df, on="date")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7954             copy=copy,
#    7955             indicator=indicator,
# -> 7956             validate=validate,
#    7957         )
#    7958
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# ...

# %%
inner = pd.merge(df, df_rate,  on='Tarih', how='inner')

# %%
inner
# Out:
#                                              title  \
# 0                   Endekste 101.000 sağlam destek
# 1      Analistlerden sanayi verisi yorumları geldi
# 2              Bankalar uçarken havayolları iniyor
# 3        Şirket haberleri ve tavsiyeleri 13/3/2019
# 4        Şirket haberleri ve tavsiyeleri 12/3/2019
# ...                                            ...
# 2075                   22 hisse için teknik analiz
# 2076               Kamu bankaları borsada düşüyor!
# 2077  Akbank Direkt'in kârı 150 şube kârına ulaştı
# 2078               İşte Türkiye'den çıkacak devler
# 2079          Türk bankaları için çok önemli uyarı
#
#                                                 content       Tarih   time  \
# 0     BIST 100, 103 bini aşağı geçtiğinde hedge şart...  15.03.2019  09:27
# 1                                                   NaN  15.03.2019  13:56
# 2     BOEING'in üretiminde kusurlu olup olmadığı inc...  15.03.2019  10:00
# ...
